# %%
from model import Model

# %%
model = Model(scale = 2, infectionChance = 0.1, contactLength = 20)

# %%
model.initialise()

# %%
model.show()

# %%
model.iterate(10)

# %%
model.show()

# %%
model.count
# Out:
# EverestValue{60}

# %%
model.chron
# Out:
# EverestValue{60.0}

# %%
model.store()

# %%
model.iterate(10)
# Out:
# ---------------------------------------------------------------------------
# EndModel                                  Traceback (most recent call last)
# <ipython-input-77-c82a1ed22d3a> in <module>
# ----> 1 model.iterate(10)
#
# ~/workspace/mount/everest/builts/_voyager.py in iterate(self, n, silent)
#      77                 raise VoyagerNotInitialised
#      78         for i in range(n):
# ---> 79             self._iterate()
#      80     @_voyager_changed_state
#      81     def _iterate(self):
#
# ~/workspace/mount/crisis_model/model.py in _iterate(self)
#     167         self.locals.initialise()
#     168     def _iterate(self):
# --> 169         self.locals.iterate()
#     170         super()._iterate()
#     171     def _out(self):
#
# ~/workspace/mount/crisis_model/model.py in iterate()
#     126             rng = self.locals.rng = np.random.default_rng(get_stepSeed())
#     127             if not len(indicated.nonzero()[0]):
# --> 128                 raise EndModel
# ...

# %%
model.count
# Out:
# EverestValue{65}

# %%
model.load(60)
