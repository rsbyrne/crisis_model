# %%
from crisis_model.model import Model

# %%
model1 = Model(scale = 1, aspect = 1.1, initialIndicated = 100)
model1.initialise(silent = True)
model1.iterate(15)
model2 = Model(scale = 1.5, aspect = 1.5)
model2[...] = model1
display(model1.show())
display(model2.show())
